# %%
import pandas as pd
from sqlalchemy import Table, Column, Integer, String, MetaData
from sqlalchemy import create_engine

# %%
data = pd.read_csv('../../data/data.csv')

# %%
data
# Out:
#            budget      id               original_title  \
# 0      30000000.0     862                    Toy Story
# 1      65000000.0    8844                      Jumanji
# 2             0.0   15602             Grumpier Old Men
# 3      16000000.0   31357            Waiting to Exhale
# 4             0.0   11862  Father of the Bride Part II
# ...           ...     ...                          ...
# 44259         0.0   30840                   Robin Hood
# 44260         0.0  111109          Siglo ng Pagluluwal
# 44261         0.0   67758                     Betrayal
# 44262         0.0  227506          Satana likuyushchiy
# 44263         0.0  461257                     Queerama
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 1      When siblings Judy and Peter discover an encha...   17.015539
# 2      A family wedding reignites the ancient feud be...   11.712900
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44264 entries, 0 to 44263
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   budget                      44264 non-null  float64
#  1   id                          44264 non-null  int64
#  2   original_title              44264 non-null  object
#  3   overview                    44264 non-null  object
#  4   popularity                  44264 non-null  float64
#  5   release_date                44264 non-null  datetime64[ns]
#  6   revenue                     44264 non-null  float64
#  7   runtime                     44264 non-null  float64
#  8   status                      44264 non-null  object
#  9   title                       44264 non-null  object
#  10  vote_average                44264 non-null  float64
#  11  vote_count                  44264 non-null  float64
#  12  genres_clean                44264 non-null  object
# ...

# %%
data.release_date = pd.to_datetime(data['release_date'], format='%Y-%m-%d', errors='coerce')

# %%
data['revenue'][1]
# Out:
# np.float64(262797249.0)

# %%
data['release_date']
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 44259   1991-05-13
# 44260   2011-11-17
# 44261   2003-08-01
# 44262   1917-10-21
# 44263   2017-06-09
# Name: release_date, Length: 44264, dtype: datetime64[ns]

# %%
# Crear la conexión con la base de datos
engine = create_engine('postgresql+psycopg2://movies_user:root123@localhost:5432/movies_recommendations')

# %%
data.to_sql('movies', engine, if_exists='replace', index=False)
# Out:
# 264

# %%
df = pd.read_sql_table('movies', engine)

# %%
type(df['release_date'][1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp
